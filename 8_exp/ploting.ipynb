# %%
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib import font_manager as fm
import pandas as pd
import numpy as np
from datetime import datetime,timedelta

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary)
plt.plot(expreince,software_engineer_salary)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary)
plt.plot(expreince,software_engineer_salary)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist")
plt.plot(expreince,software_engineer_salary,label ="software_engineer")
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend(loc="lower right")
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",color="r")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g")
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",color="r",linestyle="--")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":")
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".")
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",linewidth=6,color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".",linewidth=6)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",linewidth=6,color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".",linewidth=6)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.tight_layout()
plt.show()

# %%
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",linewidth=6,color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".",linewidth=6)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.stackplot(expreince,data_scientist_salary,software_engineer_salary,colors="g")
plt.title("Salary")
plt.xlabel("expreince")
plt.ylabel("Salary")
plt.show()

# %%
plt.style.use("dark_background")
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",linewidth=6,color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".",linewidth=6)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.style.use("seaborn-v0_8-dark")
expreince = [1,3,4,5,7,8,10,12]
data_scientist_salary = [6500,9280,12050,13200,16672,21000,23965,29793]
software_engineer_salary = [9020, 12873, 15725, 18000, 19790, 20196, 25769,32000]
plt.plot(expreince,data_scientist_salary,label="Data scientist",linewidth=6,color="r",linestyle="--",marker="o")
plt.plot(expreince,software_engineer_salary,label ="software_engineer",color="g",linestyle=":",marker=".",linewidth=6)
plt.title("Salary by expirence")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.legend()
plt.savefig("plot1.png")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
x = ["A","B","C","D"]
y = [3,8,1,10]
plt.bar(x,y)
plt.show()

# %%
plt.style.use("seaborn-v0_8-paper")
plt.bar(expreince,data_scientist_salary,color="b")
plt.title("Salary of data scientist")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.grid(True)
plt.show()

# %%
plt.style.use("tableau-colorblind10")
plt.bar(expreince,data_scientist_salary,color="b",label="data scientist salary")
plt.plot(expreince,software_engineer_salary,color="g",label="software engineer salary")
plt.title("Salary")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.grid(False)
plt.show()

# %%
wid = 0.2
plt.style.use("fivethirtyeight")
plt.bar(expreince,data_scientist_salary,color="b",label="data scientist salary",width=wid)
plt.title("Salary")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.bar(expreince,data_scientist_salary,color="r",label="data scientist salary")
plt.bar(expreince,software_engineer_salary,color="g",label="software engineer salary")
plt.title("Salary")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.grid(False)
plt.show()

# %%
expreince_indexes = np.arange(len(expreince))
width = 0.4
plt.style.use("fivethirtyeight")
plt.bar(expreince_indexes - width,software_engineer_salary, color="g",width=width,linewidth=3,label= "Software Engineers" )
plt.bar(expreince_indexes+width,data_scientist_salary,color="r",linewidth=3,width=width, label= "Data Scientists")
plt.title("Salary")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.grid(False)
plt.show()

# %%
expreince_indexes = np.arange(len(expreince))
width = 0.4
plt.style.use("fivethirtyeight")
plt.bar(expreince_indexes - width,software_engineer_salary, color="g",width=width,linewidth=3,label= "Software Engineers" )
plt.bar(expreince_indexes+width,data_scientist_salary,color="r",linewidth=3,width=width, label= "Data Scientists")
plt.title("Salary")
plt.xlabel("Expirence")
plt.ylabel("Salary")
plt.tight_layout()
plt.legend()
plt.xticks(ticks=expreince_indexes,labels=expreince)
plt.grid(False)
plt.show()

# %%
plt.title("Pie Chart")
slices = [60,40]
plt.pie(slices)
plt.tight_layout()
plt.show()

# %%
list1= [40,56,72,38,4]
plt.pie(list1)
plt.show()

# %%
persons = ["Josh","Berkay","Maria","Michael","Anastacia"]
plt.pie(list1,labels=persons)
plt.show()

# %%
plt.pie(list1,labels=persons,startangle=180)
plt.show()

# %%
myexplode = [0,0.2, 0, 0, 0]
plt.pie(list1,labels=persons,startangle=180,explode=myexplode)
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.rcParams['font.size'] = 20
plt.pie(list1,labels=persons,startangle=180,explode=myexplode,shadow=True)
plt.show()

# %%
colors = ["black","g","y","hotpink","#4CAF70"]
plt.figure(figsize=(10,20))
plt.rcParams['font.size'] = 20
plt.pie(list1,labels=persons,startangle=180,explode=myexplode,shadow=True,colors=colors)
plt.show()

# %%
plt.pie(list1,labels=persons,startangle=180,explode=myexplode,shadow=True,colors=colors)
plt.legend()
plt.show()

# %%
plt.pie(list1,labels=persons,startangle=180,explode=myexplode,shadow=True,colors=colors)
plt.legend(title="persons")
plt.show()

# %%
plt.pie(list1,labels=persons,startangle=180,explode=myexplode,shadow=True,colors=colors,autopct="%1.1f%%")
plt.legend(title="persons")
plt.show()

# %%
fig = plt.figure(1, figsize=(6,6))

ax = fig.add_axes([0.1, 0.1, 0.8, 0.8])

plt.title('Raining Hogs and Dogs')
labels = 'Frogs', 'Hogs', 'Dogs', 'Logs'
fracs = [15,30,45, 10]

patches, texts, autotexts = ax.pie(fracs, labels=labels, autopct='%1.1f%%')

proptease = fm.FontProperties()
proptease.set_size('xx-small')

plt.setp(autotexts, fontproperties=proptease)
plt.setp(texts, fontproperties=proptease)

plt.show()

# %%
days = [1,2,3,4,5,6]
sleep = [6,7,5,8,6,7]
drinking_water =   [2,2,1,2,1,1]
work =  [5,7,10,8,6,9]
exercise=  [3,3,0,1,3,2]
plt.style.use("fivethirtyeight")
plt.plot([],[],color="green",label='sleep',linewidth=3)
plt.plot([],[],color="blue",label="driniking water",linewidth=3)
plt.plot([],[],color="red",label="work",linewidth=3)
plt.plot([],[],color="orange",label="play",linewidth=3)
plt.stackplot(days,sleep,drinking_water,work,exercise,colors=['green','blue','red','orange'])
plt.xlabel('days')
plt.ylabel('activities')
plt.title("6 days routine stack example")
plt.tight_layout()
plt.legend(loc="lower right")
plt.show()

# %%
stock1= [5,3,3,6,1,8,2,7,9]
stock2= [2,4,1,3,5,0,3,1,0]
stock3= [2,2,5,1,3,1,4,1,0]

days =[1,2,3,4,5,6,7,8,9]


stocks = ['stock1','stock2','stock3']
colors=["#F9CDAD", "#FC9D9A", "#83AF9B"]

plt.title("Stack plot of stock Rates")
plt.stackplot(days,stock1,stock2,stock3,labels=stocks,colors=colors)
plt.legend()
plt.tight_layout()
plt.show()

# %%
notes = [30,74,94,14,55,47,63,28,88,44,53,18,66,74,81]
plt.style.use("fivethirtyeight")
plt.hist(notes)
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.hist(notes ,color='r')
plt.title("NOtes")
plt.xlabel("Notes")
plt.ylabel("Person")
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.hist(notes ,color='r',edgecolor='black')
plt.title("NOtes")
plt.xlabel("Notes")
plt.ylabel("Person")
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")
plt.hist(notes ,color='r',edgecolor='black',bins=5)
plt.title("NOtes")
plt.xlabel("Notes")
plt.ylabel("Person")
plt.grid(False)
plt.show()

# %%
bins = [10,45,65,80,100]
plt.style.use("fivethirtyeight")
plt.hist(notes ,color='r',edgecolor='black',bins=bins)
plt.title("NOtes")
plt.xlabel("Notes")
plt.ylabel("Person")
plt.grid(False)
plt.show()

# %%
x = np.random.normal(170,10,250)
plt.hist(x,color="gray",edgecolor="black")
plt.title("Normal Distribution")
plt.xlabel("Numbers")
plt.ylabel("count")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
df = pd.read_csv(r"c:\Users\mehta\Downloads\archive\HRDataset_v14.csv")

# %%
df.head()
# Out:
#               Employee_Name  EmpID  MarriedID  MaritalStatusID  GenderID  \
# 0       Adinolfi, Wilson  K  10026          0                0         1
# 1  Ait Sidi, Karthikeyan     10084          1                1         1
# 2         Akinkuolie, Sarah  10196          1                1         0
# 3              Alagbe,Trina  10088          1                1         0
# 4          Anderson, Carol   10069          0                2         0
#
#    EmpStatusID  DeptID  PerfScoreID  FromDiversityJobFairID  Salary  ...  \
# 0            1       5            4                       0   62506  ...
# 1            5       3            3                       0  104437  ...
# 2            5       5            3                       0   64955  ...
# 3            1       5            3                       0   64991  ...
# 4            5       5            3                       0   50825  ...
#
#       ManagerName  ManagerID RecruitmentSource PerformanceScore  \
# ...

# %%
plt.style.use("fivethirtyeight")
bins=[40000,55000,70000,85000,100000,120000]
plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black")
plt.title("Salaries of the worker")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")
bins=[40000,55000,70000,85000,100000,120000]
plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black",log=True)
plt.title("Salaries of the worker")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
plt.style.use("fivethirtyeight")
salary_mean = df.Salary.mean()
salary_median = df.Salary.median()
bins=[40000,55000,70000,85000,100000,120000]
plt.hist(df.Salary,bins=bins,color="blue",edgecolor="black",log=True)
plt.axvline(salary_mean,color="gray",label="salary_mean",linewidth=3)
plt.axvline(salary_median,color="green",label="salary median",linewidth=3)
plt.title("Salaries of the worker")
plt.xlabel("Salary")
plt.ylabel("Count")
plt.tight_layout()
plt.grid(False)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]

plt.title("Exam grades")
plt.scatter(first_exam_grades,second_exam_grades)
plt.tight_layout()
plt.xlabel("First exam grades")
plt.ylabel("Second exam grades")
plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]

plt.title("Exam grades")
plt.scatter(first_exam_grades,second_exam_grades,s=100,color='r')
plt.tight_layout()
plt.xlabel("First exam grades")
plt.ylabel("Second exam grades")
plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
sizes = np.array([20,50,100,200,500,1000,60,90,10,300])
plt.title("Exam grades")
plt.scatter(first_exam_grades,second_exam_grades,s=sizes,color='r')
plt.tight_layout()
plt.xlabel("First exam grades")
plt.ylabel("Second exam grades")
plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
sizes = np.array([20,50,100,200,500,1000,60,90,10,300])
plt.title("Exam grades")
plt.scatter(first_exam_grades,second_exam_grades,s=sizes,color='r',marker="x")
plt.tight_layout()
plt.xlabel("First exam grades")
plt.ylabel("Second exam grades")
plt.grid(True)
plt.show()

# %%
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
first_study_hours = [6,8,3,9,9,1,4,2,2,5]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
second_study_hours = [2,7,1,5,3,3,2,6,3,2]
plt.scatter(first_exam_grades,first_study_hours,s=100,color="green",marker="x")
plt.scatter(second_exam_grades,second_study_hours,s=100,color="red")
plt.tight_layout()
plt.xlabel("Exam Grades")
plt.ylabel("Study Hours")

plt.grid(True)
plt.show()

# %%
colors = [7, 5, 9, 7, 5, 7, 2, 5, 3, 7]
sizes = [209, 486, 381, 255, 191, 315, 185, 228, 174,538]
first_exam_grades = [89, 90, 70, 89, 100, 80, 90, 100, 80, 34]
first_study_hours = [6,8,3,9,9,1,4,2,2,5]
second_exam_grades = [30, 29, 49, 48, 100, 48, 38, 45, 20, 30]
second_study_hours = [2,7,1,5,3,3,2,6,3,2]
plt.scatter(first_exam_grades,second_exam_grades,s=sizes,c=colors,cmap="Blues",edgecolors="black")
cbar = plt.colorbar()
cbar.set_label("Exam Grades")
plt.tight_layout()
plt.xlabel("Exam Grades")
plt.ylabel("Study Hours")

plt.grid(True)
plt.show()

# %%
x = [0,3,6,9,13,15,19,23,26,29,33,35,39,41,47,56] 
y = [5,8,13,16,17,20,25,26,30,33,37,39,41,44,48,59]
[x,y] = np.meshgrid(x,y)
z = np.sqrt(x**2+y**2)
fig,ax=plt.subplots(1,1)
ax.contour(x,y,z)
ax.set_title("Contour Plot")
ax.set_xlabel("x values")
ax.set_ylabel("y values")
plt.show()

# %%
x = [0,3,6,9,13,15,19,23,26,29,33,35,39,41,47,56] 
y = [5,8,13,16,17,20,25,26,30,33,37,39,41,44,48,59]
[x,y] = np.meshgrid(x,y)
z = np.sqrt(x**2+y**2)
fig,ax=plt.subplots(1,1)
ax.contourf(x,y,z)
ax.set_title("Contour Plot")
ax.set_xlabel("x values")
ax.set_ylabel("y values")
plt.show()

# %%
x = [0,3,6,9,13,15,19,23,26,29,33,35,39,41,47,56] 
y = [5,8,13,16,17,20,25,26,30,33,37,39,41,44,48,59]

data = [x,y]
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
bp = ax.violinplot(data)
plt.grid(False)
plt.title("violin plot")
plt.show()

# %%
dates = [
    datetime(2021, 3, 10),
    datetime(2021, 3, 13),
    datetime(2021, 3, 14),
    datetime(2021, 3, 15),
    datetime(2021, 3, 16),
    datetime(2021, 3, 17),
    datetime(2021, 3, 18),
    datetime(2021, 3, 19)
]

values = [0,3,4,7,5,3,5,6]
plt.title("Time Series")
plt.plot_date(dates,values)
plt.xticks(rotation='vertical')
plt.show()

# %%
dates = [
    datetime(2021, 3, 10),
    datetime(2021, 3, 13),
    datetime(2021, 3, 14),
    datetime(2021, 3, 15),
    datetime(2021, 3, 16),
    datetime(2021, 3, 17),
    datetime(2021, 3, 18),
    datetime(2021, 3, 19)
]

values = [0,3,4,7,5,3,5,6]
plt.title("Time Series")
plt.plot_date(dates,values,linestyle="solid",marker="o",ms=20,mfc='r',c='b')
plt.xticks(rotation='vertical')
plt.xlabel("Dates")
plt.ylabel("values")
plt.grid(False)
plt.show()
# Out:
# C:\Users\mehta\AppData\Local\Temp\ipykernel_17096\438043343.py:14: UserWarning: marker is redundantly defined by the 'marker' keyword argument and the fmt string "o" (-> marker='o'). The keyword argument will take precedence.
#   plt.plot_date(dates,values,linestyle="solid",marker="o",ms=20,mfc='r',c='b')

# %%
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]
plt.boxplot(Salaries)
plt.title("Box Plot of Salaries")
plt.ylabel("Salaries")
plt.show()

# %%
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]
plt.boxplot(Salaries,notch=True)
plt.title("Box Plot of Salaries")
plt.ylabel("Salaries")
plt.show()

# %%
green_diamond = dict(markerfacecolor='g', marker='D')
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]
plt.boxplot(Salaries,notch=True,flierprops=green_diamond)
plt.title("Box Plot of Salaries")
plt.ylabel("Salaries")
plt.show()

# %%
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]
plt.boxplot(Salaries,notch=True,showfliers=False)
plt.title("Box Plot of Salaries")
plt.ylabel("Salaries")
plt.show()

# %%
Salaries = [6900,7500,4700,11997,22000,16550,9655,8670,15090,29000,7600,14980,1250]
plt.boxplot(Salaries,notch=True,showfliers=True,vert=False)
plt.title("Box Plot of Salaries")
plt.ylabel("Salaries")
plt.show()

# %%
data = np.random.random(( 6 , 6 )) 
plt.imshow(data,cmap="autumn")
plt.title("2d-map")
plt.show()

# %%
sns.heatmap(data,linewidths=0.5,cmap="coolwarm")
plt.title("sns heatmap")
plt.show()

# %%
plt.pcolormesh(data,cmap='summer')
plt.title("2d heatmap")
plt.show()

# %%
df = pd.read_csv("flights.csv")

# %%
df.head()
# Out:
#    id  year month  passengers
# 0   1  1949   Jan         112
# 1   2  1949   Feb         118
# 2   3  1949   Mar         132
# 3   4  1949   Apr         129
# 4   5  1949   May         121

# %%
df = df.pivot("month","year","passengers")
# Out:
# C:\Users\mehta\AppData\Local\Temp\ipykernel_17096\3803566984.py:1: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df = df.pivot("month","year","passengers")

# %%
sns.heatmap( df , linewidth = 0.5 , cmap = 'YlGn' ) 
  
plt.title( "Flights Heat Map" ) 
plt.show()
